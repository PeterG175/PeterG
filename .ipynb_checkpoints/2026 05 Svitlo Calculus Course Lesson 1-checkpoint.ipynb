# %% [markdown]
# # Welcome to My Website
# This is my second Quarto-powered page

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 7, 6, 3, 10]

plt.plot(x, y)
plt.title("My Second Chart")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
