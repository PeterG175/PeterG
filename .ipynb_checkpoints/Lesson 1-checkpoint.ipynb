# %% [raw]
# ---
# title: "Lesson 1"
# ---

# %% [markdown]
# # Lesson 1: Application of differenciation
# Hello Svitlo student! Within this lesson, we are going to try and understand why we learn about differenciation without looking at too much Maths. I hope you enjoy and if there are any mistakes or have any questions then you can email me on 'ppgaskell@outlook.com'.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 7, 6, 3, 10]

plt.plot(x, y)
plt.title("My Second Chart")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
